# %% [markdown]
# # Exercícios
#
# #### 01. Numpy
#
# ---
#
# <img src="https://selecao.letscode.com.br/favicon.png" width="40px" style="position: absolute; top: 0px; right: 40px; border-radius: 5px;" />

# %% [markdown]
# ### Para entregar! 🔥

# %% [markdown]
# **04. Construa a matriz ilustrada pela figura abaixo. Em seguida, obtenha os slices (fatiamentos) destacados em cada cor. Em outras palavras, utilizando o conceito de slices, crie um novo array que contenha os dados destacados em vermelho, azul, roxo e verde.**
#
# ![Slices em arrays - Q11](https://lh3.googleusercontent.com/TEYs3x4bTQ8OVk54ZIOzBRFN6k6HMKgdl3KDxKjREkVJYs0fBwkkMhDlLo29JN1HyN6NOgjvvnNQ7dZrvi6crgH6SB4-KT09nQSd1SIUV8YP087IK3ud3C3rkMPQxn5AzsS-jsCElZQ=w2400)

# %%
import numpy as np

# %%
mtx = np.arange(60).reshape((-1, 10))[:,:6]

# %%
mtx
# Out:
# array([[ 0,  1,  2,  3,  4,  5],
#        [10, 11, 12, 13, 14, 15],
#        [20, 21, 22, 23, 24, 25],
#        [30, 31, 32, 33, 34, 35],
#        [40, 41, 42, 43, 44, 45],
#        [50, 51, 52, 53, 54, 55]])

# %%
mtx[:4]
# Out:
# array([[ 0,  1,  2,  3,  4,  5],
#        [10, 11, 12, 13, 14, 15],
#        [20, 21, 22, 23, 24, 25],
#        [30, 31, 32, 33, 34, 35]])

# %%
mtx[:4:3, :3]
# Out:
# array([[ 0,  1,  2],
#        [30, 31, 32]])

# %%
mtx[:4:3, :3:2]
# Out:
# array([[ 0,  2],
#        [30, 32]])

# %%
mtx[[0, 3]]
# Out:
# array([[ 0,  1,  2,  3,  4,  5],
#        [30, 31, 32, 33, 34, 35]])

# %%
arr = np.array([1, 2, 3])

# %%
np.arange(0, 6)
np.arange(10, 16)
np.arange(20, 26)
# Out:
# array([20, 21, 22, 23, 24, 25])

# %%
[ np.arange(i * 10, (i * 10) + 6) for i in range(6) ]
# Out:
# [array([0, 1, 2, 3, 4, 5]),
#  array([10, 11, 12, 13, 14, 15]),
#  array([20, 21, 22, 23, 24, 25]),
#  array([30, 31, 32, 33, 34, 35]),
#  array([40, 41, 42, 43, 44, 45]),
#  array([50, 51, 52, 53, 54, 55])]

# %%
np.vstack([ np.arange(i * 10, (i * 10) + 6) for i in range(6) ])
# Out:
# array([[ 0,  1,  2,  3,  4,  5],
#        [10, 11, 12, 13, 14, 15],
#        [20, 21, 22, 23, 24, 25],
#        [30, 31, 32, 33, 34, 35],
#        [40, 41, 42, 43, 44, 45],
#        [50, 51, 52, 53, 54, 55]])

# %%
[[d+u for u in range(0,6)] for d in range(0,60,10)]
# Out:
# [[0, 1, 2, 3, 4, 5],
#  [10, 11, 12, 13, 14, 15],
#  [20, 21, 22, 23, 24, 25],
#  [30, 31, 32, 33, 34, 35],
#  [40, 41, 42, 43, 44, 45],
#  [50, 51, 52, 53, 54, 55]]

# %% [markdown]
# **05. Nessa questão, iremos praticar o conceito de indexação em imagens! Pois é, caso você ainda não saiba, as imagens são formadas com conjuntos de *pixels*, e esses *pixels* são números inteiros (entre 0 e 255). Sendo assim, quando carregamos uma imagem no Python, essa imagem será armazenada em um matriz (Numpy), ou seja, cada *pixel* dessa imagem será um elemento dessa matriz.**
#
# No entanto, é importante que você também saiba que uma imagem colorida é composta por três matrizes, visto que uma imagem colorida é formada por 3 cores básicas: vermelho, verde e azul. Esse é o famoso padrão RGB. Portanto, sua imagem será armazenada em um array tridimensional.
#
# Sabendo disso, sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical. Mas, calma... vamos te dar uma ajuda.
#
# Primeiro, você precisa instalar a biblioteca skimage para carregar a imagem, além da biblioteca do matplotlib para exibir a imagem (veremos essa biblioteca com mais detalhes nesse curso!), caso você ainda não tenha elas instaladas, claro. Para isso, utilize o comando `pip install scikit-image matplotlib`, se você estiver utilizando o pip, ou `conda install scikit-image matplotlib`, se estiver utilizando o Anaconda.
#
# Em seguida, observe o código abaixo; ele te mostra como você pode carregar uma imagem e exibi-la. Lembrando... **Sua missão será carregar uma imagem colorida (em jpg) e exibir apenas a metade dessa imagem, tanto na horizontal quanto na vertical.**
#
# ```Python
# from skimage import io
# import numpy as np
# import matplotlib.pyplot as plt
#
# img = io.imread('images/numpy-logo.jpg') # Carregamento da imagem
#
# print(type(img))
#
# plt.imshow(img) # Exibição da imagem
# ```

# %%
# Lendo a imagem por meio da URL dela

from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('https://supermariorun.com/assets/img/stage/mario03.png') # Carregamento da imagem

print(type(img))

print(img.shape)

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>
# (898, 727, 4)

# %%
# Lendo a imagem a partir de um arquivo local (na nossa máquina)

from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('images/mario.jpeg') # Carregamento da imagem

print(type(img))

print(img.shape)

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>
# (500, 500, 3)

# %%
# Fazendo um slice para obter apenas uma região da imagem (a parte da barriga do Mario)
img[250,200:300,0]
# Out:
# array([ 33,  35,  29,  33,  74, 136, 193, 223, 201, 208, 214, 214, 215,
#        213, 208, 199, 185, 179, 188, 192, 155,  92,  54,  47,  43,  34,
#         35,  38,  35,  24,  22,  26,  30,  30,  30,  30,  30,  30,  32,
#         32,  31,  31,  31,  31,  31,  31,  31,  31,  31,  31,  31,  32,
#         32,  33,  33,  32,  30,  29,  30,  31,  31,  32,  32,  32,  30,
#         31,  32,  33,  32,  32,  32,  29,  30,  29,  29,  28,  28,  28,
#         26,  25,  27,  24,  24,  24,  22,  23,  22,  21,  18,  19,  23,
#         25,  25,  27,  35,  46,  81, 220, 244, 254], dtype=uint8)

# %%
plt.imshow(img[250:300,200:300])

# %%
2**8 # Quantidade de valores que podem ser armazenados com 8 bits
# Out:
# 256

# %%
# uint8: unsigned int 8 [bits] = 1 byte
img.dtype
# Out:
# dtype('uint8')

# %%
img.itemsize # Tamanho em bytes reservado para cada elemento do ndarray
# Out:
# 1

# %%
# Criando um array para verificar o dtype e itemsize dele
arr = np.array([1, 2, 3])

# %%
arr.dtype # 64 bits >> 8 bytes
# Out:
# dtype('int64')

# %%
arr.itemsize # Cada elemento dispõe de 8 bytes para armazenar o conteúdo
# Out:
# 8

# %%
arr_bool = np.array([True, False])

# %%
arr_bool.dtype
# Out:
# dtype('bool')

# %%
arr_bool.itemsize
# Out:
# 1

# %% [markdown]
# ### Conversão RGB para Grayscale
#
# $$
#   Y = 0.299\cdot R + 0.587\cdot G + 0.114\cdot B
# $$

# %%
# Colorida: 3 canais (RGB)
# Escala de cinza: 1 canal (Cinza)

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
# Obtendo/separando cada um dos canais da imagem
red = img[:,:,0]
green = img[:,:,1]
blue = img[:,:,2]

# %%
img_gray = (red * 0.299) + (green * 0.587) + (blue * 0.114)

# %%
img_gray.shape
# Out:
# (500, 500)

# %%
img_gray.dtype
# Out:
# dtype('float64')

# %%
img_gray = img_gray.astype('uint8')

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# #### Método: média simples

# %%
img_gray_mean = (red * 0.333) + (green * 0.333) + (blue * 0.333)

# %%
img_gray_mean = img_gray_mean.astype('uint8')

# %%
plt.imshow(img_gray_mean, cmap='gray')

# %%
img_diff = np.abs(img_gray.astype('int32') - img_gray_mean.astype('int32')).astype('uint8')

# %%
img_diff.max()
# Out:
# 32

# %%
img_diff.min()
# Out:
# 0

# %%
plt.imshow(img_diff, cmap='gray')
