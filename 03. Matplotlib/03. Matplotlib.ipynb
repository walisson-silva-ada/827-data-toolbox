# %% [markdown]
# # 3. Matplotlib
# ---
#
# <img style="position: absolute; top: 15px; right: 100px; border-radius: 5px;" src="https://matplotlib.org/3.2.1/_static/logo2_compressed.svg" width="200px" />
# <img src="https://selecao.letscode.com.br/favicon.png" width="40px" style="position: absolute; top: 15px; right: 40px; border-radius: 5px;" />

# %% [markdown]
# Assim como o NumPy e o Pandas, o [Matplotlib](http://matplotlib.org/) é uma das bibliotecas que fazem parte do núcleo do [SciPy](https://www.scipy.org/) para visualização de dados 2-D.

# %% [markdown]
# ## Antes de tudo...

# %% [markdown]
# ### Instalação
#
# Se você tem o Anaconda instalado, você provavelmente já possui a biblioteca instalada.
#
# Para checar se você já tem, no Jupyter Notebook ou interpretador do Python, rode:
#
# ```python
# import matplotlib
# ```
#
# Se não der erro, é porque está tudo ok!
#
# Caso você tenha um erro, será necessário instalar. Para isso, rode o comando no prompt/terminal que possua acesso ao comando:
#
# ```
# pip install matplotlib
# ```

# %%
# !pip install matplotlib

# %% [markdown]
# ## 1. Parâmetros de Gráficos do Matplotlib
# ---
#
# <img
#      alt="Parâmetros do Matplotlib"
#      src="https://matplotlib.org/3.1.0/_images/anatomy.png"
#      style="width: 600px; border-radius: 10px"
#  />

# %%
# figure >> axes >> axis

# %%
# Importação
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 2. Plotagem Básica
# ---
#
# - Gráficos Simples
# - Gráficos com múltiplas curvas

# %% [markdown]
# ### 2.1. Plotagem com Listas

# %%
plt.plot([10, 20, 30, 40, 50]) # Gráfico de linha

# %% [markdown]
# ### 2.2. Plotagem com Arrays

# %%
x = np.arange(-np.pi, np.pi, 0.01)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %% [markdown]
# ### 2.3. Plotagem com DataFrames
#
# Vamos utilizar o dataset [`life_expectancy.csv`](https://s3-sa-east-1.amazonaws.com/lcpi/87a076e6-c0f4-48dc-9c45-2e17c70c9ab3.csv).

# %%
df = pd.read_csv('https://s3-sa-east-1.amazonaws.com/lcpi/87a076e6-c0f4-48dc-9c45-2e17c70c9ab3.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Life Expectancy Country
# 0           0  1950            49.56  Brazil
# 1           1  1951            49.98  Brazil
# 2           2  1952            50.41  Brazil
# 3           3  1953            50.83  Brazil
# 4           4  1954            51.25  Brazil

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Life Expectancy', 'Country'], dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Year  Life Expectancy Country
# 0  1950            49.56  Brazil
# 1  1951            49.98  Brazil
# 2  1952            50.41  Brazil
# 3  1953            50.83  Brazil
# 4  1954            51.25  Brazil

# %%
df.describe()
# Out:
#               Year  Life Expectancy
# count    22.000000        22.000000
# mean   1955.000000        54.908182
# std       3.236694         4.065168
# min    1950.000000        49.560000
# 25%    1952.250000        51.477500
# 50%    1955.000000        53.680000
# 75%    1957.750000        58.897500
# max    1960.000000        62.600000

# %%
df.describe(include=['object'])
# Out:
#        Country
# count       22
# unique       2
# top     Brazil
# freq        11

# %%
df.Country.unique()
# Out:
# array(['Brazil', 'EUA'], dtype=object)

# %%
df_brazil = df[df['Country'] == 'Brazil']
df_usa = df[df['Country'] == 'EUA']

# %%
df_brazil.shape
# Out:
# (11, 3)

# %%
df_usa.shape
# Out:
# (11, 3)

# %%
plt.plot(df_brazil.Year, df_brazil['Life Expectancy'])

# %%
plt.plot(df_usa.Year, df_usa['Life Expectancy'])

# %%
# Plotagem das linhas (gráficos)
plt.plot(df_brazil.Year, df_brazil['Life Expectancy'], label='Brasil')
plt.plot(df_usa.Year, df_usa['Life Expectancy'], label='EUA')

# Recursos de estilização
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida (anos de idade)')
plt.grid()
plt.legend()

# %%
plt.figure() # Criando uma nova figura

plt.plot(x, y, x, np.cos(x))
plt.legend(['Seno', 'Cosseno'])
plt.show()

# %%
# Redimensionar o tamanho da figura
plt.figure(figsize=(16, 7))

# Plotagem das linhas (gráficos)
plt.plot(df_brazil.Year, df_brazil['Life Expectancy'], label='Brasil')
plt.plot(df_usa.Year, df_usa['Life Expectancy'], label='EUA')

# Recursos de estilização
plt.title('Expectativa de Vida: Brasil x EUA')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida (anos de idade)')
plt.grid()
plt.legend()

plt.savefig('exemplo.png', facecolor='white')

plt.show()

# %%
# Configurando o tema do Matplotlib
plt.style.use('seaborn')

# %%
# Redimensionar o tamanho da figura
plt.figure(figsize=(16, 7))

# Plotagem das linhas (gráficos)
plt.plot(df_brazil.Year, df_brazil['Life Expectancy'], label='Brasil')
plt.plot(df_usa.Year, df_usa['Life Expectancy'], label='EUA')

# Recursos de estilização
plt.title('Expectativa de Vida: Brasil x EUA')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida (anos de idade)')
plt.legend(loc='upper right')

plt.savefig('exemplo.png', facecolor='white')

plt.show()

# %% [markdown]
# ### 2.4. Múltiplas Curvas
#
# #### 2.4.1. Plotando duas curvas
#
# $$
# y_1 = \sin{(x)}
# $$
#
# $$
# y_2 = \cos{(x)}
# $$

# %% [markdown]
# #### 2.4.2. Plotando três curvas
#
# $$
# y_1 = \sin{(x)}
# $$
# $$
# y_2 = \cos{(x)}
# $$
# $$
# y_3 = \sin{(x)} + \cos{(3x)}
# $$

# %%
x = np.arange(0, 2*np.pi, 0.01)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) + np.cos(3 * x)

# %%
plt.figure(figsize=(16, 9))

plt.plot(x, y1, label='$\sin{(x)}$')
plt.plot(x, y2, label='$\cos{(x)}$')
plt.plot(x, y3, label='$\sin{(x)} + \cos{(3x)}$')
plt.legend()

plt.show()
# Out:
# <div id='c48694c5-47a6-482a-9677-451eca0d3650'></div>

# %% [markdown]
# ### 2.5. Plotagem em diferentes `axes` e mesmo `figure`
#
# #### 2.5.1. Utilizado o `subplot` (API funcional)
#
# ```python
# plt.subplot(número_linhas, número_colunas, posição)
# ```
#
# Vamos plotar os mesmos $y_1$, $y_2$ e $y_3$:

# %%
# AXES 1
plt.subplot(3, 1, 1) # Estou definindo que existe um grid de 3 x 1, e estou plotando na posição 1 desse grid
plt.plot(x, y1)
plt.ylabel('$\sin{(x)}$')
plt.xlabel('x')
plt.ylim(-2, 2)
plt.yticks([-2, 0, 2])

# AXES 2
plt.subplot(3, 1, 2)
plt.plot(x, y2)
plt.ylim(-2, 2)
plt.yticks([-2, 0, 2])

# AXES 3
plt.subplot(3, 1, 3)
plt.plot(x, y3)

plt.tight_layout()

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1) # Estou definindo que existe um grid de 3 x 1, e estou plotando na posição 1 desse grid
plt.plot(x, y1)

plt.subplot(1, 3, 2)
plt.plot(x, y2)

plt.subplot(1, 3, 3)
plt.plot(x, y3)

# %% [markdown]
# Agora, vamos plotar os mesmos $y_1$, $y_2$, $y_3$ e, adicionalmente, um $y_4$, em que:
#
# $$
# y_4 = \cos{(x)} + \sin{(5x)}
# $$

# %%
y4 = np.cos(x) + np.sin(5*x)

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y1)

plt.subplot(2, 2, 2)
plt.plot(x, y2)

plt.subplot(2, 2, 3)
plt.plot(x, y3)

plt.subplot(2, 2, 4)
plt.plot(x, y4)

plt.tight_layout()

# %% [markdown]
# #### 2.5.2. Utilizando o `subplots` (API orientada a objetos)

# %%
# %matplotlib inline

# %%
figure, axes = plt.subplots(nrows=2, ncols=2, sharex=True)

figure.set(figwidth=16, figheight=8)

axes[0,0].plot(x, y1)
axes[0,0].set_ylabel('$\sin{(x)}$')

axes[0,1].plot(x, y2)
axes[0,1].set_title('Cosseno de x')

axes[1,0].plot(x, y3)

axes[1,1].plot(x, y4)

plt.xlim(0, 2 * np.pi)
# Out:
# (0.0, 6.283185307179586)

# %%
figure, axes = plt.subplots(nrows=3, ncols=1)

axes[0].plot(x, y1)

# %%
figure, axes = plt.subplots(nrows=1, ncols=3)

axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# ```python
# figure.add_axes([posicao_x_inicial, posicao_y_inicial, distancia_x, distancia_y])
# ```

# %%
figure = plt.figure(figsize=(14, 5))

axes1 = figure.add_axes([0.1, 0.1, 0.8, 0.8], zorder=1)
axes1.plot(x, y1)

axes2 = figure.add_axes([0.55, 0.65, 0.2, 0.2], zorder=2)
axes2.plot(x, y2)

# %%
fig = plt.figure()

grid = fig.add_gridspec(3, hspace=0)

axes = grid.subplots()

axes[0].plot(x, y1)
axes[1].plot(x, y2)
axes[2].plot(x, y3)

plt.show()

# %% [markdown]
# ### Exercícios
#
# 1. Crie um array x, começando de 1 até 5, com passo um passo de 0.01 entre os elementos. Depois calcule as seguintes funções sobre esse array:
#
# $$y_1 = \frac{\sin(x)}{x}$$
# $$y_2 = \frac{2^x}{20}$$
#
# Por fim, plot essas duas funções, em função do x, ambas em uma mesma figura e em um mesmo axes. Adicione um label para cada curva e, seguida, adicione uma legenda no gráfico para identificar cada curva.
#
# 2. Utilizando os mesmos dados utilizados na questão anterior, plote as duas curvas (funções) em uma mesma figura, porém, em dois axes distintos (um abaixo do outro).

# %% [markdown]
# ## 3. Estilização dos Gráficos
# ---
#
# - `color`
# - `linewidth`
# - `linestyle`
# - `marker`
# - `fontsize`
# - `fontfamily`
# - `fontweight`
# - Utilização de LaTeX
# - `alpha`
# - ...

# %% [markdown]
# ### Temas
#
# [Documentação](https://matplotlib.org/3.1.0/gallery/style_sheets/style_sheets_reference.html)

# %%
df_brazil.head()
# Out:
#    Year  Life Expectancy Country
# 0  1950            49.56  Brazil
# 1  1951            49.98  Brazil
# 2  1952            50.41  Brazil
# 3  1953            50.83  Brazil
# 4  1954            51.25  Brazil

# %%
df_usa.head()
# Out:
#     Year  Life Expectancy Country
# 11  1950            51.41     EUA
# 12  1951            54.77     EUA
# 13  1952            55.68     EUA
# 14  1953            57.49     EUA
# 15  1954            58.35     EUA

# %%
plt.style.use('default')

# %%
# Redimensionar o tamanho da figura
plt.figure(figsize=(12, 5))

# Plotagem das linhas (gráficos)
plt.plot(df_brazil.Year, df_brazil['Life Expectancy'], label='Brasil', color='green', linewidth=5, linestyle='-.')
plt.plot(df_usa.Year, df_usa['Life Expectancy'], label='EUA', color='red', marker='s', markersize=5)

# Preenchendo o intervalo entre os dados dos EUA e do Brasil
plt.fill_between(df_usa['Year'], df_usa['Life Expectancy'], df_brazil['Life Expectancy'], alpha=0.1, color='green')
# Preenchendo o intervalo entre os dados do Brasil e o seu valor mínimo
plt.fill_between(df_brazil['Year'], df_brazil['Life Expectancy'], df_brazil['Life Expectancy'].min(), alpha=0.1, color='blue')

font_label = {
  'fontsize': 12,
  'fontfamily': 'Ubuntu'
}

# Recursos de estilização
plt.title('Expectativa de Vida: Brasil x EUA', fontsize=18, fontweight='bold', fontfamily='Ubuntu')
plt.xlabel('Ano', fontdict=font_label)
plt.ylabel('Expectativa de vida (anos de idade)', fontdict=font_label)
plt.legend(loc='upper left', fontsize=14)
plt.xticks(df_brazil['Year'], rotation=30)
plt.grid()

plt.show()

# %% [markdown]
# ## 4. Outros tipos de Gráficos
# ---

# %% [markdown]
# ### 4.1. Gráficos de Barras
#
# Utilizando o dataset `life_expectancy.csv`...

# %%
plt.bar(df_brazil['Year'], df_brazil['Life Expectancy'])
# Out:
# <BarContainer object of 11 artists>

# %%
plt.bar(df_usa['Year'], df_usa['Life Expectancy'])
plt.ylim(40, 62)
# Out:
# (40.0, 62.0)

# %%
plt.bar(df_usa['Year'], df_usa['Life Expectancy'])
plt.bar(df_brazil['Year'], df_brazil['Life Expectancy'])
# Out:
# <BarContainer object of 11 artists>

# %%
plt.bar(df_usa['Year'] - 0.2, df_usa['Life Expectancy'], width=0.4, label='EUA')
plt.bar(df_brazil['Year'] + 0.2, df_brazil['Life Expectancy'], label='Brasil', width=0.4)
plt.legend()

# %% [markdown]
# #### Horizontal

# %%
plt.barh(df_brazil['Year'], df_brazil['Life Expectancy'])
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# ### 4.2. Gráfico de Dispersão

# %%
fish = pd.read_csv('https://s3-sa-east-1.amazonaws.com/lcpi/6e4f0eea-5f67-4e91-ae19-8343df190003.csv')

# %%
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
plt.scatter(fish['Width'], fish['Weight'])

# %% [markdown]
# ### 4.3. Gráfico de Pizza
#
# Utilizando o dataset `fish.csv`

# %%
plt.pie([0.2, 0.5, 0.3])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f30e46e00d0>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, ''),
#   Text(-1.0461621742897658, 0.3399186742226879, ''),
#   Text(0.6465638275138399, -0.8899186574910393, '')])

# %%
fish['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
plt.pie(fish['Species'].value_counts(), labels=fish['Species'].value_counts().index, autopct='%.2f%%', pctdistance=0.5)
plt.show()

# %% [markdown]
# ### 4.4. Histograma

# %%
dados_normal = np.random.randn(10000)

# %%
plt.hist(dados_normal, bins=50)
plt.show()
